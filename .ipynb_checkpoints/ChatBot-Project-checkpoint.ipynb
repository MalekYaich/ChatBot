# %% [markdown]
# <h1 align="center">  Application cours - NLP - Prétraitement. </h1>
# </br>

# %% [markdown]
# ## Step one: Importing libraries

# %%
import json
import string
import random
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import speech_recognition as sr

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step two: Creating a JSON file

# %%
data = {"Intents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": ["صباح النور","مرحبا","سلام علیکم","أهلاً","صباح الخير"],
              "responses": ["نهارك سعيد","سلام","مرحبا" ],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             }

]}

# %% [markdown]
# ## Step three: Processing data

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in data["Intents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %% [markdown]
# ## Step four: Designing a neural network model

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))

# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy', optimizer=tensorF.keras.optimizers.Adam(lr=0.01), metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_39 (Dense)            (None, 128)               1920
#
#  dropout_26 (Dropout)        (None, 128)               0
#
#  dense_40 (Dense)            (None, 64)                8256
#
#  dropout_27 (Dropout)        (None, 64)                0
#
#  dense_41 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 10,436
# Trainable params: 10,436
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 807ms/step - loss: 1.3222 - accuracy: 0.2500
# Epoch 2/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4041 - accuracy: 0.3750
# Epoch 3/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4082 - accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4255 - accuracy: 0.1250
# Epoch 5/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3309 - accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4340 - accuracy: 0.1250
# Epoch 7/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3192 - accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2661 - accuracy: 0.6250
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3018 - accuracy: 0.3750
# Epoch 10/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2842 - accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2830 - accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3535 - accuracy: 0.5000
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2451 - accuracy: 0.3750
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2767 - accuracy: 0.5000
# Epoch 15/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1667 - accuracy: 0.5000
# Epoch 16/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2308 - accuracy: 0.6250
# Epoch 17/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2225 - accuracy: 0.6250
# Epoch 18/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2229 - accuracy: 0.5000
# Epoch 19/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1923 - accuracy: 0.6250
# Epoch 20/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1994 - accuracy: 0.8750
# Epoch 21/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2417 - accuracy: 0.5000
# Epoch 22/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0994 - accuracy: 0.8750
# Epoch 23/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1236 - accuracy: 0.7500
# Epoch 24/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1651 - accuracy: 0.6250
# Epoch 25/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0714 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1655 - accuracy: 0.6250
# Epoch 27/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1099 - accuracy: 0.7500
# Epoch 28/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0807 - accuracy: 0.7500
# Epoch 29/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0432 - accuracy: 0.7500
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0906 - accuracy: 0.7500
# Epoch 31/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0569 - accuracy: 0.7500
# Epoch 32/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0910 - accuracy: 0.7500
# Epoch 33/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0267 - accuracy: 0.7500
# Epoch 34/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0348 - accuracy: 0.7500
# Epoch 35/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1188 - accuracy: 0.5000
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9243 - accuracy: 0.8750
# Epoch 37/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9846 - accuracy: 0.8750
# Epoch 38/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0305 - accuracy: 0.7500
# Epoch 39/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9370 - accuracy: 0.8750
# Epoch 40/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9854 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9637 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8512 - accuracy: 0.8750
# Epoch 43/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8392 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9561 - accuracy: 0.7500
# Epoch 45/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8775 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9023 - accuracy: 0.7500
# Epoch 47/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8951 - accuracy: 0.8750
# Epoch 48/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7099 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8092 - accuracy: 0.8750
# Epoch 50/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9311 - accuracy: 0.7500
# Epoch 51/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7702 - accuracy: 0.8750
# Epoch 52/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8105 - accuracy: 0.8750
# Epoch 53/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7660 - accuracy: 0.8750
# Epoch 54/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7649 - accuracy: 0.8750
# Epoch 55/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7736 - accuracy: 0.8750
# Epoch 56/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7392 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6457 - accuracy: 0.8750
# Epoch 58/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6710 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7335 - accuracy: 0.8750
# Epoch 60/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7678 - accuracy: 0.8750
# Epoch 61/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6866 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5839 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6621 - accuracy: 0.8750
# Epoch 64/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5138 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6707 - accuracy: 0.8750
# Epoch 67/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6109 - accuracy: 0.8750
# Epoch 68/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4410 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4489 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6296 - accuracy: 0.8750
# Epoch 71/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5727 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5723 - accuracy: 0.8750
# Epoch 73/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4722 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3611 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6402 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3475 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4612 - accuracy: 0.8750
# Epoch 79/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3669 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4599 - accuracy: 0.8750
# Epoch 81/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3684 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4038 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4143 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4181 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3020 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3980 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3195 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3012 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2760 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3644 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2979 - accuracy: 0.8750
# Epoch 93/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3389 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2236 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2378 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3373 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2444 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1982 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1833 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2676 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1443 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2241 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2632 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3057 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1986 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1266 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3035 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1338 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0883 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1786 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1676 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1993 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1666 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1923 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0948 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2171 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1399 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1669 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1150 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1543 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1042 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0950 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0837 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1669 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2380 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1353 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0832 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1100 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0864 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1604 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1044 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1685 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0860 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0919 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1558 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1103 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0934 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0680 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0949 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0561 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0870 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0816 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0941 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2150 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0606 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0628 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0919 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0802 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0445 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 1.0000

# %% [markdown]
# ## Step five: Building useful features

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["Intents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %% [markdown]
# ## Execution

# %%
r=sr.Recognizer()
with sr.Microphone() as source:
    print("Début")
    audio_data = r.record(source,duration=7)
    print("Reconnaissance")
    text = r.recognize_google(audio_data,language="ar-AR")
    print(text)
# Out:
# Début
# Reconnaissance
# result2:
# {   'alternative': [{'confidence': 0.90117449, 'transcript': 'السلام عليكم'}],
#     'final': True}
# السلام عليكم

# %%
while True: 
    print("كيف تريد التواصل معنا؟ انقر  0 إذا كنت تريد إرسال رسائل صوتية أو 1 إذا كنت تريد إرسال رسائل نصية")
    res=input("")
    if res=="1" :
        while True:
            newMessage = input("")
            intents = Pclass(newMessage, newWords, ourClasses)
            ourResult = getRes(intents, data)
            print(ourResult)
    
    elif res=="0" :       
        r=sr.Recognizer()
        with sr.Microphone() as source:
            while True:
                print("هيا يمكنك التحدث")
                audio_data = r.record(source,duration=5, offset=None)
                print(" يتم فهم رسالتك الصوتية. انتظر من فضلك")
                Msg = r.recognize_google(audio_data,language="ar-AR")
                print("You : ",Msg)
                intents = Pclass(Msg, newWords, ourClasses)
                ourResult = getRes(intents, data)
                print("ChatBot :",ourResult)
# Out:
# كيف تريد التواصل معنا؟ انقر  0 إذا كنت تريد إرسال رسائل صوتية أو 1 إذا كنت تريد إرسال رسائل نصية
# 1
# صباح الخير
# 1/1 [==============================] - 0s 46ms/step
# مرحبا
# مرحبا
# 1/1 [==============================] - 0s 20ms/step
# نهارك سعيد
# مرحبا fffff
# 1/1 [==============================] - 0s 20ms/step
# نهارك سعيد
