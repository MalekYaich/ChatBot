# %% [markdown]
# <h1 align="center">  Application cours - NLP - Prétraitement. </h1>
# </br>

# %%
import json
import string
import random
import nltk
#nltk.download('wordnet')
#nltk.download('omw-1.4')
import numpy as np
from nltk.stem import WordNetLemmatizer# It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import speech_recognition as sr

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mmyai\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## Step one: Importing libraries

# %% [markdown]
# ## Step two: Creating a JSON file

# %%
def get_data():
    with open("data.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

# %% [markdown]
# ## Step three: Processing data

# %%
def data_processing(data):
    lm = WordNetLemmatizer() #for getting words
    # lists
    ourClasses = []
    newWords = []
    documentX = []
    documentY = []
    # Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
    for intent in data["Intents"]:
        for pattern in intent["patterns"]:
            ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
            newWords.extend(ournewTkns)# extends the tokens
            documentX.append(pattern)
            documentY.append(intent["tag"])


        if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
            ourClasses.append(intent["tag"])

    newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
    newWords = sorted(set(newWords))# sorting words
    ourClasses = sorted(set(ourClasses))# sorting classes
    return (newWords,ourClasses,documentX,documentY)

# %%
get_data()
# Out:
# {'Intents': [{'tag': 'age',
#    'patterns': ['how old are you?'],
#    'responses': ['I am 2 years old and my birthday was yesterday']},
#   {'tag': 'greeting',
#    'patterns': ['صباح النور', 'مرحبا', 'سلام علیکم', 'أهلاً', 'صباح الخير'],
#    'responses': ['نهارك سعيد', 'سلام', 'مرحبا']},
#   {'tag': 'goodbye',
#    'patterns': ['bye', 'later'],
#    'responses': ['Bye', 'take care']},
#   {'tag': 'name',
#    'patterns': ["what's your name?", 'who are you?'],
#    'responses': ['I have no name yet',
#     'You can give me one, and I will appreciate it']}]}

# %% [markdown]
# ## Step four: Designing a neural network model

# %%
newWords,ourClasses,documentX,documentY= data_processing(get_data())
lm = WordNetLemmatizer() #for getting words

trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = np.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = np.array(list(trainingData[:, 0]))# first trainig phase
y = np.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))

# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy', optimizer=tensorF.keras.optimizers.Adam(lr=0.01), metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2432
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 10,948
# Trainable params: 10,948
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.4284 - accuracy: 0.2000
# Epoch 2/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4163 - accuracy: 0.1000
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4169 - accuracy: 0.1000
# Epoch 4/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3617 - accuracy: 0.3000
# Epoch 5/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3273 - accuracy: 0.4000
# Epoch 6/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3980 - accuracy: 0.1000
# Epoch 7/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3209 - accuracy: 0.4000
# Epoch 8/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3507 - accuracy: 0.4000
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3107 - accuracy: 0.4000
# Epoch 10/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3100 - accuracy: 0.3000
# Epoch 11/200
# 1/1 [==============================] - 0s 17ms/step - loss: 1.2860 - accuracy: 0.4000
# Epoch 12/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2341 - accuracy: 0.6000
# Epoch 13/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2976 - accuracy: 0.5000
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1439 - accuracy: 0.6000
# Epoch 15/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2606 - accuracy: 0.5000
# Epoch 16/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.2341 - accuracy: 0.8000
# Epoch 17/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0966 - accuracy: 0.8000
# Epoch 18/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1434 - accuracy: 0.6000
# Epoch 19/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1408 - accuracy: 0.7000
# Epoch 20/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0952 - accuracy: 0.7000
# Epoch 21/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1229 - accuracy: 0.6000
# Epoch 22/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0878 - accuracy: 0.9000
# Epoch 23/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1203 - accuracy: 0.6000
# Epoch 24/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9956 - accuracy: 0.8000
# Epoch 25/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1071 - accuracy: 0.7000
# Epoch 26/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0025 - accuracy: 0.6000
# Epoch 27/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9923 - accuracy: 0.8000
# Epoch 28/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0880 - accuracy: 0.7000
# Epoch 29/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9848 - accuracy: 0.8000
# Epoch 30/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8830 - accuracy: 0.8000
# Epoch 31/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9406 - accuracy: 0.7000
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9782 - accuracy: 0.8000
# Epoch 33/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8102 - accuracy: 0.8000
# Epoch 34/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.8512 - accuracy: 0.7000
# Epoch 35/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9906 - accuracy: 0.6000
# Epoch 36/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8815 - accuracy: 0.7000
# Epoch 37/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9903 - accuracy: 0.6000
# Epoch 38/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9841 - accuracy: 0.6000
# Epoch 39/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7739 - accuracy: 0.9000
# Epoch 40/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7613 - accuracy: 0.8000
# Epoch 41/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7093 - accuracy: 0.9000
# Epoch 42/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8968 - accuracy: 0.7000
# Epoch 43/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7872 - accuracy: 0.7000
# Epoch 44/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7446 - accuracy: 0.8000
# Epoch 45/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6538 - accuracy: 0.9000
# Epoch 46/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6977 - accuracy: 0.9000
# Epoch 47/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7997 - accuracy: 0.7000
# Epoch 48/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7815 - accuracy: 0.8000
# Epoch 49/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7465 - accuracy: 0.8000
# Epoch 50/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6659 - accuracy: 0.8000
# Epoch 51/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7174 - accuracy: 0.8000
# Epoch 52/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7170 - accuracy: 0.8000
# Epoch 53/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7873 - accuracy: 0.7000
# Epoch 54/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5918 - accuracy: 0.9000
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6016 - accuracy: 0.7000
# Epoch 56/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5987 - accuracy: 0.8000
# Epoch 57/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7057 - accuracy: 0.7000
# Epoch 58/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6955 - accuracy: 0.8000
# Epoch 59/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5825 - accuracy: 0.9000
# Epoch 60/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4526 - accuracy: 0.9000
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5645 - accuracy: 0.9000
# Epoch 62/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5709 - accuracy: 0.7000
# Epoch 63/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4589 - accuracy: 0.8000
# Epoch 64/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5353 - accuracy: 0.9000
# Epoch 65/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4196 - accuracy: 0.9000
# Epoch 66/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4887 - accuracy: 0.9000
# Epoch 67/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4882 - accuracy: 0.9000
# Epoch 68/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4414 - accuracy: 0.9000
# Epoch 69/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4786 - accuracy: 0.9000
# Epoch 70/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4365 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5020 - accuracy: 0.8000
# Epoch 72/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4160 - accuracy: 0.8000
# Epoch 73/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4486 - accuracy: 0.9000
# Epoch 74/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3895 - accuracy: 0.8000
# Epoch 75/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4121 - accuracy: 0.8000
# Epoch 76/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4450 - accuracy: 0.9000
# Epoch 77/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4453 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5050 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3387 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4076 - accuracy: 0.9000
# Epoch 81/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3737 - accuracy: 0.9000
# Epoch 82/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3330 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4070 - accuracy: 0.9000
# Epoch 84/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3926 - accuracy: 0.9000
# Epoch 85/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3039 - accuracy: 0.9000
# Epoch 86/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3377 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2877 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2989 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2531 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2614 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2141 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3368 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2100 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2865 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3463 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1975 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.2071 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1796 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3655 - accuracy: 0.9000
# Epoch 100/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2519 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1698 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2964 - accuracy: 0.9000
# Epoch 103/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2387 - accuracy: 0.9000
# Epoch 104/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1428 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1715 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1703 - accuracy: 0.9000
# Epoch 107/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1586 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2085 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1950 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0885 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1641 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2196 - accuracy: 0.9000
# Epoch 113/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1152 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1064 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0928 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1194 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2403 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1422 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1366 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0797 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1437 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0899 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0865 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1715 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1246 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0858 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1038 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0951 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1502 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0821 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1126 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1173 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1631 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1156 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.2034 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0881 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0960 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0611 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0771 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0662 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1211 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1344 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1183 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0729 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0971 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0885 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0664 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0984 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1053 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0843 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1207 - accuracy: 0.9000
# Epoch 185/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0996 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0147 - accuracy: 1.0000

# %%
model_json = ourNewModel.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
ourNewModel.save_weights('model.h5')

# %% [markdown]
# ## Step five: Building useful features

# %%
def ourText(text):
    lm = WordNetLemmatizer()
    newtkns = nltk.word_tokenize(text)
    newtkns = [lm.lemmatize(word) for word in newtkns]
    return newtkns

def wordBag(text, vocab):
    newtkns = ourText(text)
    bagOwords = [0] * len(vocab)
    for w in newtkns:
        for idx, word in enumerate(vocab):
            if word == w:
                bagOwords[idx] = 1
    return np.array(bagOwords)

def Pclass(text, vocab, labels,model):
    bagOwords = wordBag(text, vocab)
    ourResult = model.predict(np.array([bagOwords]))[0]
    newThresh = 0.2
    yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

    yp.sort(key=lambda x: x[1], reverse=True)
    newList = []
    for r in yp:
        newList.append(labels[r[0]])
    return newList

def getRes(firstlist, fJson):
    tag = firstlist[0]
    listOfIntents = fJson["Intents"]
    for i in listOfIntents:
        if i["tag"] == tag:
            ourResult = random.choice(i["responses"])
            break
    return ourResult

# %% [markdown]
# ## Execution

# %%
def get_answer(text,model):
    data=get_data()
    newWords, ourClasses,_,__=data_processing(data)
    intents = Pclass(text, newWords, ourClasses,model)
    return getRes(intents, data)

# %%
get_answer("سلام",ourNewModel)
# Out:
# 1/1 [==============================] - 0s 187ms/step
# 'مرحبا'
