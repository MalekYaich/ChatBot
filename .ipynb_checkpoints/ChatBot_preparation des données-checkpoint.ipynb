# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer
from nltk import FreqDist, pos_tag
from textblob import Word

# %% [markdown]
# # I.Prétraitement :

# %%
data=pd.read_csv("TALN_data.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Question', 'reponse', 'type'], dtype='object')

# %%
data
# Out:
#       Unnamed: 0                                           Question  \
# 0              0  اظن اني احتاج لاستشار ة مختص في العلاج السلوكي...
# 1              1  ابنتي 14 سنه تعاني منذ سنتين من الوسواس القهري...
# 2              2  مرحبا دكتوره انا ولدي توفى امامي وبين يدي توفى...
# 3              3  أشعر بإكتئاب شديد وحزن وابكي واخاف من المستقبل...
# 4              4  ماعلاج الخوف الاجتماعي ونكران الذات لمن هو في ...
# ...          ...                                                ...
# 2090        2187  تعالجت لسني وسحبت العصب جلستين حصل لي ظروف وما...
# 2091        2188  أنا رحت ع أساس أكشف وأركب تقويم لاكن الدكتور ح...
# 2092        2189  السلام عليكم ورحمه الله وبركاته ، لقد وقعت على...
# 2093        2190  مرحبا انا سيده عمري 41 قبل عده اشهر انجبت ابنت...
# 2094        2191  هل يتم عمل تقويم اسنان اذا كان بعض الاضراس غير...
#
#                                                 reponse           type
# 0                         ما هي المشكله التي تعاني منها      علم النفس
# 1     يعتمد ذلك على فهم الأعراض بشكل شامل والتشخيص ا...      علم النفس
# 2     تحتاج لمزيد من التشخيص لدى متخصص لمعرفة تفاصيل...      علم النفس
# 3     مساء الخير.... انت بحاجه لزيارة طبيب نفسي.. لي...      علم النفس
# 4                       صديقي بحاجه لمراجعة معالج سلوكي      علم النفس
# ...                                                 ...            ...
# 2090  اثناء الحمل نمتنع فقط عن عمل الاشعه للحامل كما...  أمراض الأسنان
# 2091  نعم قبل تركيب التقويم يحب ان يتم علاج كل تسوسا...  أمراض الأسنان
# 2092  اذا كانت الاسنان قد رجعت للخلف بسبب الصدمه خلا...  أمراض الأسنان
# 2093  احيانا تحدث تغييرات لثوية بعد الحمل والولادة ن...  أمراض الأسنان
# 2094  نعم التقويم أساساَ لمثل هكذا حالات.لكن يبقى ال...  أمراض الأسنان
#
# [2095 rows x 4 columns]

# %%
data1= data[data.type == "علم النفس"]

# %%
data1=data1[:50]
data1
# Out:
#     Unnamed: 0                                           Question  \
# 0            0  اظن اني احتاج لاستشار ة مختص في العلاج السلوكي...
# 1            1  ابنتي 14 سنه تعاني منذ سنتين من الوسواس القهري...
# 2            2  مرحبا دكتوره انا ولدي توفى امامي وبين يدي توفى...
# 3            3  أشعر بإكتئاب شديد وحزن وابكي واخاف من المستقبل...
# 4            4  ماعلاج الخوف الاجتماعي ونكران الذات لمن هو في ...
# 5            5                      كيف اتغلب على توتر الامتحان ؟
# 6            6             أشعر بوتر وخجل عندما أتعامل مع الاخرين
# 7            7    هل يعتبر حب البنت لللبنت كانهم حبيبان مرض نفسي؟
# 8            8           كيف احلل شخصيتي\r\nودي اعرف شخصيتي حقيقه
# 9            9  انا خطيبي ﻻ يغار علية وحبة قل كثيرا ولم يعد يه...
# 10          10  منذ عامان وانا اشعر بكرة شديد لحياتي ومزاجية ش...
# 11          11  منذ عامان شعور بكرة للحياة بعد مشكلة معي ثم بد...
# 12          12  زوجى يأخذ اوبلاكس 5مجم مضاد للذهان بناءا على ر...
# 13          13  السلام عليكم\r\nالى حضرة الدكاترة المحترمين اذ...
# 14          14  الخوف من المستقبل وتشويش بالذهن والرغبة في بعض...
# 15          15  مرحبا\r\nمنذ شهرين صار نومي متقطعاً وقليل حيث ...
# 16          16  لقد وصلت لمرحلة التفكير في الموت على الدوام ول...
# 17          17  انا اشعر بالحزن والوحدة والملل طوال حياته منذ ...
# 18          18  اعاني من الحالة النفسية السيئة و والاكتئاب و ا...
# 19          19  اشعر دائما بل اختناق وأفكر دائماً بي اشياء قد ...
# 20          20  انا عندي مشكلة نفسية واترددت كتير في اني اتعال...
# 21          21  ارجو ارشادي الى اسم وعنوان عيادة طب نفسي في بغ...
# 22          22  لدي مشكلة في التركيز وكثيراً ما أكون سرحان ولم...
# 23          23  انا اعاني من توتر النفسي وتفاقمت مع الحالة الي...
# 24          24  تعلقت في فتاة عمرها 21 , ولابعادها عني اختلقت ...
# 25          25  دخلت في قصة وفشلت وعائلتي ينتقدونني لاني لا اس...
# 26          26  كيف يستطيع الانسان ان يتخلص من تاثير صدمة نفسي...
# 27          27  ماسبب عدم الثقه بالاخرين والشعور السلبي ماقبل ...
# 28          28                    دواء للتخلص من الاكتئاب و الضيق
# 29          29  ما هو المرض اللذى يجعل صاحبه يعيش بشخصية اخرى ...
# 30          30  انا اعاني من مشكله يا اخوان وهي\r\nاني تركت شخ...
# 31          31  هل الابتريل والدباكين ممكن يعملوا تشوهات فى ال...
# 32          32  انا حامل بالشهر الرابع وزمرة دمي ب سلبي وقال ل...
# 33          33  ماذا افعل لكى اتخلص من افكارى السيئه تجاه الاخ...
# 34          34  زوجتي تعاني من ضيق الصدر وكابه في الفجر علما ب...
# 35          35  اتعلق جدا باصدقائي. اخاف بان يتركوني. اشعر بال...
# 36          36  من شهر حصلي اختناق وخفقان وعدم القدرة علي البل...
# 37          37            السلام عليكم\r\nما علاج الوسواس القهري؟
# 38          38  دائما اشع بالاكتئاب والاحباط والخوف من الخروج ...
# 39          39                      الخوف من مواجهة ومخاطبة الناس
# 40          40  السلام عليكم\r\nمن فضلكم كيف أتخلص من التوتر و...
# 41          41  أنا لدي مشاكل أخرى كالقلق والوسواس والرهاب الإ...
# 42          42  السلام عليكم لي صديقتي تعاني من اكتئاب و واضبت...
# 43          43  لدي وسواس قهري بالافكار والتخيلات لها 5 سنوات ...
# 44          44  توفي ابي منذ مدة لكني لم استطيع البكاء ابدا فى...
# 45          45                       ما هو(الذهان التأخري)؟ وشكرا
# 46          46  يعطيك العافية\r\nاعاني من كثرة الحزن والتفكير ...
# 47          47       لدي وسواس من الأمراض وانا كثيرة التفكير فيها
# 48          48  دايما حاسة اني لوحدي والناس كلها جاية عليا شاي...
# 49          49  علاج الوسواس القهري والقلق النفسي والصراخ علما...
#
#                                               reponse       type
# 0                       ما هي المشكله التي تعاني منها  علم النفس
# 1   يعتمد ذلك على فهم الأعراض بشكل شامل والتشخيص ا...  علم النفس
# 2   تحتاج لمزيد من التشخيص لدى متخصص لمعرفة تفاصيل...  علم النفس
# 3   مساء الخير.... انت بحاجه لزيارة طبيب نفسي.. لي...  علم النفس
# 4                     صديقي بحاجه لمراجعة معالج سلوكي  علم النفس
# 5   التوتر السابق للامتحانات أمر مقبول بل وصحي، لأ...  علم النفس
# 6   قد تعاني من اضطراب الرهاب الاجتماعي، أنصحك بزي...  علم النفس
# 7   قد يكون هناك عامل نفسي او مرضي وراء هذا الشعور...  علم النفس
# 8   الانسان يستطيع ان يتعرف على الكثير من خواص ذات...  علم النفس
# 9   الغيره مرحلة غير ناضجة من مراحل الحب فالحب الن...  علم النفس
# 10        تحتاج لمراجعة اقرب عيادة نفسية لتقييم حالتك  علم النفس
# 11  هذه علامات الاكتاب الظرفي يمكن علاجها بسهولة م...  علم النفس
# 12  لا يمكن اذابته في السوائل لانه سيفقد فعاليته ر...  علم النفس
# 13  تحتاج الى تشخيص اكثر دقه عياديه ولذلك من الضرو...  علم النفس
# 14  الاعراض التي تعاني منها تتطلب منك مراجعة اقرب ...  علم النفس
# 15                               راجع اقرب معالج فورا  علم النفس
# 16  تستطيع ان تستفيد من الجوانب الايمانيه في حياتك...  علم النفس
# 17  تحتاج حالتك الى ان يكون لديك رغبة في التغيير و...  علم النفس
# 18  تستطيع ان تستفيد من الجوانب الايمانيه في حياتك...  علم النفس
# 19  تحتاجين ان تمارسي تمرين الاسترخاء والتفكر الار...  علم النفس
# 20  اذا لم يكن هناك اعراض اخرى فانت تحتاجين الى تم...  علم النفس
# 21                                    ابحثي في الدليل  علم النفس
# 22  تحتاج التنظيم نمطك اليومي ومن ثم التدرب على تم...  علم النفس
# 23                        ممكن ان توصفي وضعك بشكل ادق  علم النفس
# 24  اختيارك لهذه الحجة غريب، خصوصا انك أنت الذي أر...  علم النفس
# 25  من المفيد لك ان تتدربي على التفكير الايجابي\r\...  علم النفس
# 26  الصدمة تختلف حسب طبيعتها وتختلف حسب تأثيرها\r\...  علم النفس
# 27  البيانات التي في هذا السؤال مبتوره\r\nفالثقة ل...  علم النفس
# 28  الاكتئاب والضيق انواع ومستويات تحتاج الى تقييم...  علم النفس
# 29  dissociative personality disorder\r\nوهو نوع م...  علم النفس
# 30  ستندمل هذه الجراح مع الوقت ولكن المهم الا تصري...  علم النفس
# 31  الديباكين بيعمل تشوهات للأجنة، ويمنع تناوله أث...  علم النفس
# 32                          نعم صحيح ولا تقلقي من ذلك  علم النفس
# 33  انت تعاني من تدني بالثقه بالنفس وتقييمك السي ل...  علم النفس
# 34  هذه نوبات هلع ننصح بمراجعة طبيب نفسي للتقيم وت...  علم النفس
# 35             تدريبات الثقة بالنفس مفيدة لمثل حالاتك  علم النفس
# 36  الاعراض غير كافية تحتاج الى معاينه اكلينيكية و...  علم النفس
# 37  يحتاج تحديد العلاج الى تشخيص دقيق حتى تستطيع ا...  علم النفس
# 38  تستطيع ان تستفيد من الجوانب الايمانيه في حياتك...  علم النفس
# 39  تمرينات اثبات الذات تفيد في مثل حالتك بعد استك...  علم النفس
# 40  جرب ممارسة تمارين الاسترخاء والتنفس العميق مع ...  علم النفس
# 41  الباروكستين هو العلاج الانسب للرهاب الاجتماعي ...  علم النفس
# 42  ننصحها بعمل تخطيط قلب لان بعض مضادات الاكتئاب\...  علم النفس
# 43  هنالك طرق عدة لعلاج الوسواس القهري كالعلاج الس...  علم النفس
# 44  قديكون ذلك من احد علامات الاكتىءاب انصح بمراجع...  علم النفس
# 45  لا يوجد هكذا مصطلح...\r\nالذهان: هو مرض يطلق ع...  علم النفس
# 46  قد تكون هذه اعراض للشخصية الاكتئابية او الاكتئ...  علم النفس
# 47  هنالك عدة احتمالات تشخيصية للوسواس من الامراض ...  علم النفس
# 48  السؤال يعطي بعض الاعراض التي قد تعد طبيعية في ...  علم النفس
# 49  في بعض الأحيان أدوية التشنج تظهر بعض العصبيه ....  علم النفس

# %% [markdown]
# # Tokenisation

# %%
question=[]
reponse=[]
for i in range (len (data1)):
    
    question.append(data1.Question[i].split())
    reponse.append(data1.reponse[i].split())
len(question)
# Out:
# 50

# %%
question
# Out:
# [['اظن',
#   'اني',
#   'احتاج',
#   'لاستشار',
#   'ة',
#   'مختص',
#   'في',
#   'العلاج',
#   'السلوكي',
#   'المعرفي',
#   'لكن',
#   'لا',
#   'استطيع',
#   'فعمري',
#   'فقط17',
#   'و',
#   'عائلتي',
#   'لن',
#   'تتقبل',
#   'هذا',
#   'الامر',
#   'فهل',
#   'هناك',
#   'حل',
#   'اخر',
#   'و',
#   'شكرا'],
#  ['ابنتي',
#   '14',
#   'سنه',
#   'تعاني',
#   'منذ',
#   'سنتين',
#   'من',
#   'الوسواس',
#   'القهري',
#   'ماعلاجه'],
#  ['مرحبا',
#   'دكتوره',
#   'انا',
#   'ولدي',
#   'توفى',
#   'امامي',
#   'وبين',
#   'يدي',
#   'توفى',
#   'في',
#   'جلطه',
#   'في',
#   'القلب',
#   'وانا',
#   'اعاني',
#   'من',
#   'الخوف',
#   'والقل',
#   'اتخيل',
#   'اني',
#   'سوف',
#   'تجيني',
#   'جلطه',
#   'واموت',
#   'واي',
#   'حد',
#   'يقول',
#   'عن',
#   'مرض',
#   'اخاف',
#   'جدا',
#   'واضل',
#   'افكر',
#   'فيه'],
#  ['أشعر',
#   'بإكتئاب',
#   'شديد',
#   'وحزن',
#   'وابكي',
#   'واخاف',
#   'من',
#   'المستقبل',
#   'بلغت',
#   '33سنه',
#   'بدون',
#   'زواج',
#   'ونظرة',
#   'الناس',
#   'تقتلني',
#   'لايفارقني',
#   'الاحساس',
#   'بالنقص',
#   'والدونيه',
#   'واصبحت',
#   'ولاأخرج',
#   'وكارهه',
#   'حالي',
#   'وتعيسه',
#   'وافكر',
#   'فى',
#   'الانتحار'],
#  ['ماعلاج',
#   'الخوف',
#   'الاجتماعي',
#   'ونكران',
#   'الذات',
#   'لمن',
#   'هو',
#   'في',
#   'عز',
#   'شبابه',
#   '؟',
#   ':('],
#  ['كيف', 'اتغلب', 'على', 'توتر', 'الامتحان', '؟'],
#  ['أشعر', 'بوتر', 'وخجل', 'عندما', 'أتعامل', 'مع', 'الاخرين'],
#  ['هل', 'يعتبر', 'حب', 'البنت', 'لللبنت', 'كانهم', 'حبيبان', 'مرض', 'نفسي؟'],
#  ['كيف', 'احلل', 'شخصيتي', 'ودي', 'اعرف', 'شخصيتي', 'حقيقه'],
#  ['انا',
#   'خطيبي',
#   'ﻻ',
#   'يغار',
#   'علية',
#   'وحبة',
#   'قل',
#   'كثيرا',
#   'ولم',
#   'يعد',
#   'يهتم',
#   'بي',
#   'كالسابق',
#   'رغم',
#   'انة',
#   'كان',
#   'غيورا',
#   'جدا',
#   'في',
#   'ماضي',
#   'وقد',
#   'اصبح',
#   'على',
#   'خطوبتنا',
#   '3',
#   'سنوات',
#   'ممكن',
#   'طريقة',
#   'اجعلة',
#   'يغار',
#   'ويحبني'],
#  ['منذ',
#   'عامان',
#   'وانا',
#   'اشعر',
#   'بكرة',
#   'شديد',
#   'لحياتي',
#   'ومزاجية',
#   'شديدة',
#   'وحزن',
#   'وذالالك',
#   'لحدوث',
#   'مشكلة',
#   'تلاها',
#   'اصابتي',
#   'بمرض',
#   'مزمن',
#   '؟',
#   'هل',
#   'احتاج',
#   'لعلاج',
#   'نفسي',
#   '؟'],
#  ['منذ',
#   'عامان',
#   'شعور',
#   'بكرة',
#   'للحياة',
#   'بعد',
#   'مشكلة',
#   'معي',
#   'ثم',
#   'بدائت',
#   'اتوسوس',
#   'باني',
#   'اصبت',
#   'بمرض',
#   'معين',
#   'ثم',
#   'رجعت',
#   'عن',
#   'هذة',
#   'الوسوسة',
#   'ثم',
#   'اصبت',
#   'فعلا',
#   'بربو',
#   'الصدر',
#   'لذالك',
#   'اشعر',
#   'دائما',
#   'بالحزن',
#   'والمزاجية',
#   'الشديدة،',
#   'ما',
#   'الحل؟'],
#  ['زوجى',
#   'يأخذ',
#   'اوبلاكس',
#   '5مجم',
#   'مضاد',
#   'للذهان',
#   'بناءا',
#   'على',
#   'رغبه',
#   'الطبيب',
#   'من',
#   'يوم',
#   '9/8',
#   'ولكنه',
#   'رفض',
#   'يأخده',
#   'اليوم',
#   'ومطلقا',
#   'هل',
#   'هذا',
#   'له',
#   'اثار',
#   'جانبيه',
#   'وهل',
#   'يمكن',
#   'ان',
#   'يذوب',
#   'ف',
#   'العصير',
#   'او',
#   'الشاى',
#   'ارجو',
#   'الرد',
#   'سريعا'],
#  ['السلام',
#   'عليكم',
#   'الى',
#   'حضرة',
#   'الدكاترة',
#   'المحترمين',
#   'اذا',
#   'ممكن',
#   'اريد',
#   'السؤال',
#   'عن',
#   'حالتي',
#   'حيث',
#   'اني',
#   'اعاني',
#   'من',
#   'مرض',
#   'نفسي',
#   'منذ',
#   '15',
#   'سنه',
#   'وهو',
#   'نتف',
#   'الشعر',
#   'من',
#   'اللحية',
#   'والصدر',
#   '؟',
#   'وتحسسه',
#   'في',
#   'الفم',
#   'فهل',
#   'من',
#   'علاج'],
#  ['الخوف',
#   'من',
#   'المستقبل',
#   'وتشويش',
#   'بالذهن',
#   'والرغبة',
#   'في',
#   'بعض',
#   'الاحيان',
#   'التخلص',
#   'من',
#   'الحياة',
#   'والتمني',
#   'للذهاب',
#   'الى',
#   'عالم',
#   'لا',
#   'فيه',
#   'اي',
#   'احد',
#   'واختلاط',
#   'الاهداف',
#   'و',
#   'لوم',
#   'الذات',
#   'كثيرا',
#   'لدرجة',
#   'الكره',
#   '.هل',
#   'يوجد',
#   'حل',
#   'ساعدوني'],
#  ['مرحبا',
#   'منذ',
#   'شهرين',
#   'صار',
#   'نومي',
#   'متقطعاً',
#   'وقليل',
#   'حيث',
#   'لم',
#   'انم',
#   'إلا',
#   'ساعة',
#   'او',
#   'ساعة',
#   'ونصف',
#   'على',
#   'الاكثر',
#   'وهذا',
#   'ما',
#   'اثار',
#   'لدي',
#   'الرعب',
#   'وبدأت',
#   'تناول',
#   'الحبوب',
#   'المنومة',
#   'ولكني',
#   'قطعتها',
#   'خوفاً',
#   'من',
#   'الادمان.ماذا',
#   'أفعل؟'],
#  ['لقد',
#   'وصلت',
#   'لمرحلة',
#   'التفكير',
#   'في',
#   'الموت',
#   'على',
#   'الدوام',
#   'ولم',
#   'أعد',
#   'أمارس',
#   'أي',
#   'نشاط',
#   'أحبه',
#   'ودائما',
#   'أشعر',
#   'بحزن',
#   'وبكراهية',
#   'لحياتي',
#   'ولاأتوقف',
#   'عن',
#   'التفكير',
#   'في',
#   'الانتحار',
#   'وربما',
#   'سأفعل',
#   'كيف',
#   'أتخلص',
#   'من',
#   'هذه',
#   'الافكار؟'],
#  ['انا',
#   'اشعر',
#   'بالحزن',
#   'والوحدة',
#   'والملل',
#   'طوال',
#   'حياته',
#   'منذ',
#   'ولدت....الموضوع',
#   'طويل',
#   'لا',
#   'يمكن',
#   'شرحه',
#   'في',
#   'بضع',
#   'كلمات'],
#  ['اعاني',
#   'من',
#   'الحالة',
#   'النفسية',
#   'السيئة',
#   'و',
#   'والاكتئاب',
#   'و',
#   'الهم',
#   'و',
#   'الحزن'],
#  ['اشعر',
#   'دائما',
#   'بل',
#   'اختناق',
#   'وأفكر',
#   'دائماً',
#   'بي',
#   'اشياء',
#   'قد',
#   'تزعجني',
#   'أتمنى',
#   'التخلص',
#   'من',
#   'هاذا',
#   'الشي',
#   'وشكرا',
#   '؟!'],
#  ['انا',
#   'عندي',
#   'مشكلة',
#   'نفسية',
#   'واترددت',
#   'كتير',
#   'في',
#   'اني',
#   'اتعالج',
#   'عند',
#   'دكتور',
#   'نفسي',
#   'المشكلة',
#   'في',
#   'اني',
#   'مش',
#   'بعرف',
#   'اتعامل',
#   'مع',
#   'الناس',
#   'وبتظلم',
#   'كتير',
#   'في',
#   'حياتي',
#   'من',
#   'اقرب',
#   'الناس',
#   'ليا',
#   'وبقيت',
#   'بكرهم',
#   'ياريت',
#   'حد',
#   'يساعدني',
#   'بجد'],
#  ['ارجو',
#   'ارشادي',
#   'الى',
#   'اسم',
#   'وعنوان',
#   'عيادة',
#   'طب',
#   'نفسي',
#   'في',
#   'بغداد',
#   'لولدي١٧سنة',
#   'الذي',
#   'يعاني',
#   'من',
#   'الوسواس',
#   'القهري',
#   'حسب',
#   'تشخيص',
#   'احد',
#   'الاطباء',
#   'واعتقد',
#   'انه',
#   'بحاجة',
#   'الى',
#   'معالج',
#   'نفسي',
#   'وليس',
#   'الحبوب',
#   'والدواء',
#   'فقط',
#   '.'],
#  ['لدي',
#   'مشكلة',
#   'في',
#   'التركيز',
#   'وكثيراً',
#   'ما',
#   'أكون',
#   'سرحان',
#   'ولم',
#   'أستطيع',
#   'السيطرة',
#   'على',
#   'نفسي؟',
#   'أ'],
#  ['انا',
#   'اعاني',
#   'من',
#   'توتر',
#   'النفسي',
#   'وتفاقمت',
#   'مع',
#   'الحالة',
#   'الي',
#   'الوسواس',
#   'القهري',
#   'واثر',
#   'ذالك',
#   'علي',
#   'جميع',
#   'تصرفاتي',
#   'اريد',
#   'وحالتي',
#   'النفسية',
#   'حل',
#   '؟'],
#  ['تعلقت',
#   'في',
#   'فتاة',
#   'عمرها',
#   '21',
#   ',',
#   'ولابعادها',
#   'عني',
#   'اختلقت',
#   'موضوع',
#   'اني',
#   'مثلي',
#   'الجنس',
#   ',',
#   'والمشكلة',
#   'انني',
#   'الان',
#   'اصبحت',
#   'ادخل',
#   'مواقع',
#   'المثليين',
#   'واتخيل',
#   'نفسي',
#   'مثلهم',
#   'واتخيلها',
#   'معي',
#   ',',
#   'الى',
#   'الان',
#   'انا',
#   'على',
#   'تواصل',
#   'بها'],
#  ['دخلت',
#   'في',
#   'قصة',
#   'وفشلت',
#   'وعائلتي',
#   'ينتقدونني',
#   'لاني',
#   'لا',
#   'اساعد',
#   'امي',
#   'كثيرا',
#   'في',
#   'تنظيف',
#   'المنزل',
#   'ودائما',
#   'يقال',
#   'لي',
#   'اني',
#   'فاشلة',
#   'وغبية',
#   'واشعر',
#   'بالضعف',
#   'وابكي',
#   'كث',
#   'واصبحت',
#   'سريعة',
#   'الغضب',
#   'واريد',
#   'اكون',
#   'سيئة',
#   'ماذا',
#   'افعل'],
#  ['كيف',
#   'يستطيع',
#   'الانسان',
#   'ان',
#   'يتخلص',
#   'من',
#   'تاثير',
#   'صدمة',
#   'نفسيه',
#   'شديدة',
#   'اصابته'],
#  ['ماسبب',
#   'عدم',
#   'الثقه',
#   'بالاخرين',
#   'والشعور',
#   'السلبي',
#   'ماقبل',
#   'النوم؟؟؟'],
#  ['دواء', 'للتخلص', 'من', 'الاكتئاب', 'و', 'الضيق'],
#  ['ما',
#   'هو',
#   'المرض',
#   'اللذى',
#   'يجعل',
#   'صاحبه',
#   'يعيش',
#   'بشخصية',
#   'اخرى',
#   'موازية',
#   'لشخصيته',
#   'ولكنه',
#   'بأسم',
#   'وحياة',
#   'اجتماعية',
#   'مختلفة',
#   'عن',
#   'حقيقته',
#   '...',
#   'ويعيش',
#   'بالشخصيتين',
#   'معا',
#   'وﻻ',
#   'احد',
#   'يعلم',
#   'بذلك',
#   'غيره',
#   'هو',
#   'فقط',
#   '؟؟؟؟',
#   'ارجو',
#   'الرد'],
#  ['انا',
#   'اعاني',
#   'من',
#   'مشكله',
#   'يا',
#   'اخوان',
#   'وهي',
#   'اني',
#   'تركت',
#   'شخصا',
#   'احببته',
#   'كثيرا',
#   'وانا',
#   'اعاني',
#   'من',
#   'مشكلات',
#   'في',
#   'حياتي',
#   'وانهيار',
#   'احلامي',
#   'امامي'],
#  ['هل',
#   'الابتريل',
#   'والدباكين',
#   'ممكن',
#   'يعملوا',
#   'تشوهات',
#   'فى',
#   'الاجنه',
#   'انا',
#   'باخد',
#   'ابتريل',
#   '2',
#   'مل',
#   'جرام',
#   'فى',
#   'اليوم',
#   'بقالى',
#   '10',
#   'سنوات',
#   'وديباكيت',
#   '200',
#   'مل',
#   'جرام',
#   'واحياناا',
#   'عند',
#   'زعلى',
#   'بتحصلى',
#   'الحاله',
#   'بس',
#   'مش',
#   'كمله'],
#  ['انا',
#   'حامل',
#   'بالشهر',
#   'الرابع',
#   'وزمرة',
#   'دمي',
#   'ب',
#   'سلبي',
#   'وقال',
#   'لي',
#   'دكتور',
#   'ان',
#   'كانت',
#   'زمرة',
#   'دم',
#   'زوجي',
#   'ايجابية',
#   'فيجب',
#   'ان',
#   'اعطى',
#   'في',
#   'الشهر',
#   'السابع',
#   'حقنة',
#   'وعند',
#   'الولادة',
#   'حقنة',
#   'هل',
#   'هذا',
#   'الروتين',
#   'صحيح',
#   'لحالتي؟...وشكرا'],
#  ['ماذا',
#   'افعل',
#   'لكى',
#   'اتخلص',
#   'من',
#   'افكارى',
#   'السيئه',
#   'تجاه',
#   'الاخرين',
#   'وشكوكى',
#   'الزائده',
#   'بها',
#   'وشعورى',
#   'الدائم',
#   'بانى',
#   'مريضه',
#   'نفسيا'],
#  ['زوجتي',
#   'تعاني',
#   'من',
#   'ضيق',
#   'الصدر',
#   'وكابه',
#   'في',
#   'الفجر',
#   'علما',
#   'بانها',
#   'تستعمل',
#   'حبوب',
#   'اونليفت',
#   'للتنحيف',
#   'عمرها',
#   '37سنه',
#   'والحاله',
#   'تنتابها',
#   'بين',
#   'الحين',
#   'والاخر',
#   'وليست',
#   'مستمره'],
#  ['اتعلق',
#   'جدا',
#   'باصدقائي.',
#   'اخاف',
#   'بان',
#   'يتركوني.',
#   'اشعر',
#   'بالوحده',
#   'و',
#   'اخاف',
#   'الجلوس',
#   'لوحدي',
#   'في',
#   'البيت.',
#   'لدي',
#   'محاولات',
#   'بالانتحار.',
#   'اشعر',
#   'باليأس',
#   'و',
#   'الحزن',
#   'الشديد.',
#   'متعلق',
#   'جدا',
#   'بصديقي.',
#   'نوبات',
#   'غضب.',
#   'قليل',
#   'التركيز'],
#  ['من',
#   'شهر',
#   'حصلي',
#   'اختناق',
#   'وخفقان',
#   'وعدم',
#   'القدرة',
#   'علي',
#   'البلع',
#   'وعدم',
#   'التركيز',
#   'وحسست',
#   'ان',
#   'هالموت',
#   'لكن',
#   'صرت',
#   'منيح',
#   'شوي',
#   'لكن',
#   'كل',
#   'مافكر',
#   'في',
#   'الموضوع',
#   'تجيني',
#   'الحالة',
#   'واحس',
#   'بالموت',
#   'وملل',
#   'بالحياة',
#   'وعدم',
#   'المتعة',
#   'بالحياه'],
#  ['السلام', 'عليكم', 'ما', 'علاج', 'الوسواس', 'القهري؟'],
#  ['دائما',
#   'اشع',
#   'بالاكتئاب',
#   'والاحباط',
#   'والخوف',
#   'من',
#   'الخروج',
#   'صباحا',
#   'وتروادنى',
#   'فترة',
#   'الصباح',
#   'اكتئاب',
#   'حادا',
#   'ووسواس',
#   'فى',
#   'كل',
#   'شى',
#   'بجانب',
#   'الشك',
#   'فى',
#   'كل',
#   'من',
#   'حولى',
#   'من',
#   'اصدقاء',
#   'او',
#   'عائلة',
#   'او',
#   'حتى',
#   'غرباء',
#   'فهل',
#   'من',
#   'علاج',
#   'فعال'],
#  ['الخوف', 'من', 'مواجهة', 'ومخاطبة', 'الناس'],
#  ['السلام',
#   'عليكم',
#   'من',
#   'فضلكم',
#   'كيف',
#   'أتخلص',
#   'من',
#   'التوتر',
#   'والخوف',
#   'في',
#   'الامتحان'],
#  ['أنا',
#   'لدي',
#   'مشاكل',
#   'أخرى',
#   'كالقلق',
#   'والوسواس',
#   'والرهاب',
#   'الإجتماعي',
#   'وما',
#   'يترتب',
#   'على',
#   'الأخير',
#   'من',
#   'تلعثم',
#   'وتأتأة',
#   'وسوء',
#   'التعبير',
#   'أحيانا',
#   'وليس',
#   'دائما',
#   'هل',
#   'زبركسا',
#   'أو',
#   'باروكستين',
#   'مناسب',
#   'مع',
#   'دوائي',
#   'الفلوناكسول'],
#  ['السلام',
#   'عليكم',
#   'لي',
#   'صديقتي',
#   'تعاني',
#   'من',
#   'اكتئاب',
#   'و',
#   'واضبت',
#   'على',
#   'اخد',
#   'مضاد',
#   'الاكتئاب',
#   'لمدة',
#   'سنة',
#   'ونص',
#   'واتحسنت',
#   'وقطعته',
#   'تدريجيا',
#   'بدون',
#   'استشارة',
#   'من',
#   'طبيبتها',
#   'وبعد',
#   'اربع',
#   'اشهر',
#   'اصبح',
#   'يؤلمها',
#   'قليلا',
#   'قلبها',
#   'وبعضا',
#   'من',
#   'اعراض',
#   'الاكتئاب',
#   'في',
#   'مرحلته',
#   'الاولى',
#   'ف',
#   'بمادا',
#   'تنصحها'],
#  ['لدي',
#   'وسواس',
#   'قهري',
#   'بالافكار',
#   'والتخيلات',
#   'لها',
#   '5',
#   'سنوات',
#   'حاولت',
#   'بكل',
#   'الطرق',
#   'ولا',
#   'فائدة',
#   'لا',
#   'زال',
#   'الوسواس',
#   'موجود',
#   'حسب',
#   'ما',
#   'قرأت',
#   'انه',
#   'لا',
#   'يذهب',
#   'الا',
#   'بتناول',
#   'الادوية',
#   'فما',
#   'نصيحتكم..علما',
#   'اني',
#   'مصاب',
#   'بفشل',
#   'كلوي'],
#  ['توفي',
#   'ابي',
#   'منذ',
#   'مدة',
#   'لكني',
#   'لم',
#   'استطيع',
#   'البكاء',
#   'ابدا',
#   'فى',
#   'الاول',
#   'قلت',
#   'يمكن',
#   'تكون',
#   'من',
#   'الصدمة',
#   'لكن',
#   'الان',
#   'احاول',
#   'ان',
#   'اتذكر',
#   'كلامه',
#   'او',
#   'شيىء',
#   'يخصه',
#   'لا',
#   'استطيع',
#   'اشعر',
#   'انه',
#   'حلم',
#   'انا',
#   'اعيش',
#   'كانه',
#   'لم',
#   'يكن',
#   'في',
#   'حياتي'],
#  ['ما', 'هو(الذهان', 'التأخري)؟', 'وشكرا'],
#  ['يعطيك',
#   'العافية',
#   'اعاني',
#   'من',
#   'كثرة',
#   'الحزن',
#   'والتفكير',
#   'السلبي',
#   'في',
#   'اكثر',
#   'الاوقات',
#   'ونادرا',
#   'ما',
#   'افرح'],
#  ['لدي', 'وسواس', 'من', 'الأمراض', 'وانا', 'كثيرة', 'التفكير', 'فيها'],
#  ['دايما',
#   'حاسة',
#   'اني',
#   'لوحدي',
#   'والناس',
#   'كلها',
#   'جاية',
#   'عليا',
#   'شايفة',
#   'نفسي',
#   'وحشة',
#   'بس',
#   'مش',
#   'شكل',
#   'مزاجي',
#   'بيتغير',
#   'دايما',
#   'ودايما',
#   'حاسة',
#   'بحزن',
#   'حتي',
#   'في',
#   'وقت',
#   'الفرحة'],
#  ['علاج',
#   'الوسواس',
#   'القهري',
#   'والقلق',
#   'النفسي',
#   'والصراخ',
#   'علما',
#   'بأن',
#   'أعاني',
#   'من',
#   'الصراع',
#   'ومنتظم',
#   'بالعلاج',
#   'ولكن',
#   'القلق',
#   'النفسي',
#   'حاجز',
#   'لي',
#   'بالحياه',
#   'وأطر',
#   'لحجز',
#   'نفسي',
#   'منفردا',
#   'عن',
#   'الأخرين',
#   'أفيدوني',
#   'ماعلاجي']]

# %% [markdown]
# # Elimination de la ponctuation, stop words et stemming

# %%
stop_words = set(stopwords.words('arabic'))
lancaster=LancasterStemmer()

# %%
question1=[lancaster.stem(word) for quest in question for word in quest  if lancaster.stem(word) not in stop_words  and word.isalpha()]

# %%
reponse1= [lancaster.stem(word) for rep in reponse for word in rep  if lancaster.stem(word) not in stop_words  and word.isalpha()]

# %%
question_freq=FreqDist(question1)

# %%
question_freq.most_common()
# Out:
# [('اني', 10),
#  ('انا', 10),
#  ('نفسي', 8),
#  ('اعاني', 7),
#  ('اشعر', 7),
#  ('الوسواس', 6),
#  ('فى', 6),
#  ('ان', 6),
#  ('لدي', 6),
#  ('او', 5),
#  ('الى', 5),
#  ('القهري', 4),
#  ('وانا', 4),
#  ('الخوف', 4),
#  ('جدا', 4),
#  ('الناس', 4),
#  ('مشكلة', 4),
#  ('دائما', 4),
#  ('السلام', 4),
#  ('عليكم', 4),
#  ('علاج', 4),
#  ('استطيع', 3),
#  ('فهل', 3),
#  ('حل', 3),
#  ('تعاني', 3),
#  ('مرض', 3),
#  ('اخاف', 3),
#  ('أشعر', 3),
#  ('ولم', 3),
#  ('سنوات', 3),
#  ('ممكن', 3),
#  ('يمكن', 3),
#  ('ارجو', 3),
#  ('احد', 3),
#  ('التفكير', 3),
#  ('الحالة', 3),
#  ('الحزن', 3),
#  ('مش', 3),
#  ('حياتي', 3),
#  ('انه', 3),
#  ('التركيز', 3),
#  ('النفسي', 3),
#  ('الان', 3),
#  ('الاكتئاب', 3),
#  ('وعدم', 3),
#  ('احتاج', 2),
#  ('سنه', 2),
#  ('مرحبا', 2),
#  ('توفى', 2),
#  ('امامي', 2),
#  ('جلطه', 2),
#  ('تجيني', 2),
#  ('حد', 2),
#  ('شديد', 2),
#  ('وحزن', 2),
#  ('وابكي', 2),
#  ('المستقبل', 2),
#  ('بدون', 2),
#  ('واصبحت', 2),
#  ('الانتحار', 2),
#  ('الذات', 2),
#  ('توتر', 2),
#  ('الامتحان', 2),
#  ('الاخرين', 2),
#  ('شخصيتي', 2),
#  ('يغار', 2),
#  ('اصبح', 2),
#  ('عامان', 2),
#  ('بكرة', 2),
#  ('لحياتي', 2),
#  ('شديدة', 2),
#  ('بمرض', 2),
#  ('معي', 2),
#  ('اصبت', 2),
#  ('الصدر', 2),
#  ('بالحزن', 2),
#  ('مضاد', 2),
#  ('ولكنه', 2),
#  ('اليوم', 2),
#  ('اثار', 2),
#  ('الرد', 2),
#  ('اريد', 2),
#  ('التخلص', 2),
#  ('ساعة', 2),
#  ('الحبوب', 2),
#  ('ودائما', 2),
#  ('بحزن', 2),
#  ('أتخلص', 2),
#  ('النفسية', 2),
#  ('اختناق', 2),
#  ('وشكرا', 2),
#  ('كتير', 2),
#  ('دكتور', 2),
#  ('وليس', 2),
#  ('فقط', 2),
#  ('علي', 2),
#  ('عمرها', 2),
#  ('افعل', 2),
#  ('السلبي', 2),
#  ('مل', 2),
#  ('جرام', 2),
#  ('حقنة', 2),
#  ('علما', 2),
#  ('لوحدي', 2),
#  ('بالحياه', 2),
#  ('والخوف', 2),
#  ('اكتئاب', 2),
#  ('وسواس', 2),
#  ('دايما', 2),
#  ('حاسة', 2),
#  ('اظن', 1),
#  ('لاستشار', 1),
#  ('مختص', 1),
#  ('العلاج', 1),
#  ('السلوكي', 1),
#  ('المعرفي', 1),
#  ('فعمري', 1),
#  ('عائلتي', 1),
#  ('تتقبل', 1),
#  ('الامر', 1),
#  ('اخر', 1),
#  ('شكرا', 1),
#  ('ابنتي', 1),
#  ('سنتين', 1),
#  ('ماعلاجه', 1),
#  ('دكتوره', 1),
#  ('ولدي', 1),
#  ('وبين', 1),
#  ('يدي', 1),
#  ('القلب', 1),
#  ('والقل', 1),
#  ('اتخيل', 1),
#  ('واموت', 1),
#  ('واي', 1),
#  ('يقول', 1),
#  ('واضل', 1),
#  ('افكر', 1),
#  ('بإكتئاب', 1),
#  ('واخاف', 1),
#  ('بلغت', 1),
#  ('زواج', 1),
#  ('ونظرة', 1),
#  ('تقتلني', 1),
#  ('لايفارقني', 1),
#  ('الاحساس', 1),
#  ('بالنقص', 1),
#  ('والدونيه', 1),
#  ('ولاأخرج', 1),
#  ('وكارهه', 1),
#  ('حالي', 1),
#  ('وتعيسه', 1),
#  ('وافكر', 1),
#  ('ماعلاج', 1),
#  ('الاجتماعي', 1),
#  ('ونكران', 1),
#  ('لمن', 1),
#  ('عز', 1),
#  ('شبابه', 1),
#  ('اتغلب', 1),
#  ('بوتر', 1),
#  ('وخجل', 1),
#  ('عندما', 1),
#  ('أتعامل', 1),
#  ('يعتبر', 1),
#  ('حب', 1),
#  ('البنت', 1),
#  ('لللبنت', 1),
#  ('كانهم', 1),
#  ('حبيبان', 1),
#  ('احلل', 1),
#  ('ودي', 1),
#  ('اعرف', 1),
#  ('حقيقه', 1),
#  ('خطيبي', 1),
#  ('ﻻ', 1),
#  ('علية', 1),
#  ('وحبة', 1),
#  ('قل', 1),
#  ('يعد', 1),
#  ('يهتم', 1),
#  ('كالسابق', 1),
#  ('رغم', 1),
#  ('انة', 1),
#  ('غيورا', 1),
#  ('ماضي', 1),
#  ('وقد', 1),
#  ('خطوبتنا', 1),
#  ('طريقة', 1),
#  ('اجعلة', 1),
#  ('ويحبني', 1),
#  ('ومزاجية', 1),
#  ('وذالالك', 1),
#  ('لحدوث', 1),
#  ('تلاها', 1),
#  ('اصابتي', 1),
#  ('مزمن', 1),
#  ('لعلاج', 1),
#  ('شعور', 1),
#  ('للحياة', 1),
#  ('بدائت', 1),
#  ('اتوسوس', 1),
#  ('باني', 1),
#  ('معين', 1),
#  ('رجعت', 1),
#  ('هذة', 1),
#  ('الوسوسة', 1),
#  ('فعلا', 1),
#  ('بربو', 1),
#  ('لذالك', 1),
#  ('والمزاجية', 1),
#  ('زوجى', 1),
#  ('يأخذ', 1),
#  ('اوبلاكس', 1),
#  ('للذهان', 1),
#  ('بناءا', 1),
#  ('رغبه', 1),
#  ('الطبيب', 1),
#  ('يوم', 1),
#  ('رفض', 1),
#  ('يأخده', 1),
#  ('ومطلقا', 1),
#  ('جانبيه', 1),
#  ('وهل', 1),
#  ('يذوب', 1),
#  ('العصير', 1),
#  ('الشاى', 1),
#  ('سريعا', 1),
#  ('حضرة', 1),
#  ('الدكاترة', 1),
#  ('المحترمين', 1),
#  ('اذا', 1),
#  ('السؤال', 1),
#  ('حالتي', 1),
#  ('نتف', 1),
#  ('الشعر', 1),
#  ('اللحية', 1),
#  ('والصدر', 1),
#  ('وتحسسه', 1),
#  ('الفم', 1),
#  ('وتشويش', 1),
#  ('بالذهن', 1),
#  ('والرغبة', 1),
#  ('الاحيان', 1),
#  ('الحياة', 1),
#  ('والتمني', 1),
#  ('للذهاب', 1),
#  ('عالم', 1),
#  ('اي', 1),
#  ('واختلاط', 1),
#  ('الاهداف', 1),
#  ('لوم', 1),
#  ('لدرجة', 1),
#  ('الكره', 1),
#  ('يوجد', 1),
#  ('ساعدوني', 1),
#  ('شهرين', 1),
#  ('نومي', 1),
#  ('وقليل', 1),
#  ('انم', 1),
#  ('ونصف', 1),
#  ('الاكثر', 1),
#  ('وهذا', 1),
#  ('الرعب', 1),
#  ('وبدأت', 1),
#  ('تناول', 1),
#  ('المنومة', 1),
#  ('ولكني', 1),
#  ('قطعتها', 1),
#  ('لقد', 1),
#  ('وصلت', 1),
#  ('لمرحلة', 1),
#  ('الموت', 1),
#  ('الدوام', 1),
#  ('أعد', 1),
#  ('أمارس', 1),
#  ('نشاط', 1),
#  ('أحبه', 1),
#  ('وبكراهية', 1),
#  ('ولاأتوقف', 1),
#  ('وربما', 1),
#  ('سأفعل', 1),
#  ('والوحدة', 1),
#  ('والملل', 1),
#  ('طوال', 1),
#  ('حياته', 1),
#  ('طويل', 1),
#  ('شرحه', 1),
#  ('كلمات', 1),
#  ('السيئة', 1),
#  ('والاكتئاب', 1),
#  ('الهم', 1),
#  ('وأفكر', 1),
#  ('اشياء', 1),
#  ('تزعجني', 1),
#  ('أتمنى', 1),
#  ('هاذا', 1),
#  ('الشي', 1),
#  ('عندي', 1),
#  ('نفسية', 1),
#  ('واترددت', 1),
#  ('اتعالج', 1),
#  ('المشكلة', 1),
#  ('بعرف', 1),
#  ('اتعامل', 1),
#  ('وبتظلم', 1),
#  ('اقرب', 1),
#  ('ليا', 1),
#  ('وبقيت', 1),
#  ('بكرهم', 1),
#  ('ياريت', 1),
#  ('يساعدني', 1),
#  ('بجد', 1),
#  ('ارشادي', 1),
#  ('اسم', 1),
#  ('وعنوان', 1),
#  ('عيادة', 1),
#  ('طب', 1),
#  ('بغداد', 1),
#  ('يعاني', 1),
#  ('تشخيص', 1),
#  ('الاطباء', 1),
#  ('واعتقد', 1),
#  ('بحاجة', 1),
#  ('معالج', 1),
#  ('والدواء', 1),
#  ('أكون', 1),
#  ('سرحان', 1),
#  ('أستطيع', 1),
#  ('السيطرة', 1),
#  ('وتفاقمت', 1),
#  ('الي', 1),
#  ('واثر', 1),
#  ('ذالك', 1),
#  ('تصرفاتي', 1),
#  ('وحالتي', 1),
#  ('تعلقت', 1),
#  ('فتاة', 1),
#  ('ولابعادها', 1),
#  ('عني', 1),
#  ('اختلقت', 1),
#  ('موضوع', 1),
#  ('مثلي', 1),
#  ('الجنس', 1),
#  ('والمشكلة', 1),
#  ('انني', 1),
#  ('اصبحت', 1),
#  ('ادخل', 1),
#  ('مواقع', 1),
#  ('المثليين', 1),
#  ('واتخيل', 1),
#  ('مثلهم', 1),
#  ('واتخيلها', 1),
#  ('تواصل', 1),
#  ('دخلت', 1),
#  ('قصة', 1),
#  ('وفشلت', 1),
#  ('وعائلتي', 1),
#  ('ينتقدونني', 1),
#  ('لاني', 1),
#  ('اساعد', 1),
#  ('امي', 1),
#  ('تنظيف', 1),
#  ('المنزل', 1),
#  ('يقال', 1),
#  ('فاشلة', 1),
#  ('وغبية', 1),
#  ('واشعر', 1),
#  ('بالضعف', 1),
#  ('كث', 1),
#  ('سريعة', 1),
#  ('الغضب', 1),
#  ('واريد', 1),
#  ('اكون', 1),
#  ('سيئة', 1),
#  ('يستطيع', 1),
#  ('الانسان', 1),
#  ('يتخلص', 1),
#  ('تاثير', 1),
#  ('صدمة', 1),
#  ('نفسيه', 1),
#  ('اصابته', 1),
#  ('ماسبب', 1),
#  ('عدم', 1),
#  ('الثقه', 1),
#  ('بالاخرين', 1),
#  ('والشعور', 1),
#  ('ماقبل', 1),
#  ('دواء', 1),
#  ('للتخلص', 1),
#  ('الضيق', 1),
#  ('المرض', 1),
#  ('اللذى', 1),
#  ('يجعل', 1),
#  ('صاحبه', 1),
#  ('يعيش', 1),
#  ('بشخصية', 1),
#  ('اخرى', 1),
#  ('موازية', 1),
#  ('لشخصيته', 1),
#  ('بأسم', 1),
#  ('وحياة', 1),
#  ('اجتماعية', 1),
#  ('مختلفة', 1),
#  ('حقيقته', 1),
#  ('ويعيش', 1),
#  ('بالشخصيتين', 1),
#  ('معا', 1),
#  ('وﻻ', 1),
#  ('يعلم', 1),
#  ('بذلك', 1),
#  ('غيره', 1),
#  ('مشكله', 1),
#  ('اخوان', 1),
#  ('وهي', 1),
#  ('تركت', 1),
#  ('شخصا', 1),
#  ('احببته', 1),
#  ('مشكلات', 1),
#  ('وانهيار', 1),
#  ('احلامي', 1),
#  ('الابتريل', 1),
#  ('والدباكين', 1),
#  ('يعملوا', 1),
#  ('تشوهات', 1),
#  ('الاجنه', 1),
#  ('باخد', 1),
#  ('ابتريل', 1),
#  ('بقالى', 1),
#  ('وديباكيت', 1),
#  ('واحياناا', 1),
#  ('زعلى', 1),
#  ('بتحصلى', 1),
#  ('الحاله', 1),
#  ('كمله', 1),
#  ('حامل', 1),
#  ('بالشهر', 1),
#  ('الرابع', 1),
#  ('وزمرة', 1),
#  ('دمي', 1),
#  ('سلبي', 1),
#  ('وقال', 1),
#  ('كانت', 1),
#  ('زمرة', 1),
#  ('دم', 1),
#  ('زوجي', 1),
#  ('ايجابية', 1),
#  ('فيجب', 1),
#  ('اعطى', 1),
#  ('الشهر', 1),
#  ('السابع', 1),
#  ('وعند', 1),
#  ('الولادة', 1),
#  ('الروتين', 1),
#  ('صحيح', 1),
#  ('لكى', 1),
#  ('اتخلص', 1),
#  ('افكارى', 1),
#  ('السيئه', 1),
#  ('وشكوكى', 1),
#  ('الزائده', 1),
#  ('وشعورى', 1),
#  ('الدائم', 1),
#  ('بانى', 1),
#  ('مريضه', 1),
#  ('نفسيا', 1),
#  ('زوجتي', 1),
#  ('ضيق', 1),
#  ('وكابه', 1),
#  ('الفجر', 1),
#  ('بانها', 1),
#  ('تستعمل', 1),
#  ('حبوب', 1),
#  ('اونليفت', 1),
#  ('للتنحيف', 1),
#  ('والحاله', 1),
#  ('تنتابها', 1),
#  ('الحين', 1),
#  ('والاخر', 1),
#  ('وليست', 1),
#  ('مستمره', 1),
#  ('اتعلق', 1),
#  ('بان', 1),
#  ('بالوحده', 1),
#  ('الجلوس', 1),
#  ('محاولات', 1),
#  ('باليأس', 1),
#  ('متعلق', 1),
#  ('نوبات', 1),
#  ('قليل', 1),
#  ('شهر', 1),
#  ('حصلي', 1),
#  ('وخفقان', 1),
#  ('القدرة', 1),
#  ('البلع', 1),
#  ('وحسست', 1),
#  ('هالموت', 1),
#  ('صرت', 1),
#  ('منيح', 1),
#  ('شوي', 1),
#  ('مافكر', 1),
#  ('الموضوع', 1),
#  ('واحس', 1),
#  ('بالموت', 1),
#  ('وملل', 1),
#  ('بالحياة', 1),
#  ('المتعة', 1),
#  ('اشع', 1),
#  ('بالاكتئاب', 1),
#  ('والاحباط', 1),
#  ('الخروج', 1),
#  ('صباحا', 1),
#  ('وتروادنى', 1),
#  ('فترة', 1),
#  ('الصباح', 1),
#  ('حادا', 1),
#  ('ووسواس', 1),
#  ('شى', 1),
#  ('بجانب', 1),
#  ('الشك', 1),
#  ('حولى', 1),
#  ('اصدقاء', 1),
#  ('عائلة', 1),
#  ('غرباء', 1),
#  ('فعال', 1),
#  ('مواجهة', 1),
#  ('ومخاطبة', 1),
#  ('فضلكم', 1),
#  ('التوتر', 1),
#  ('مشاكل', 1),
#  ('أخرى', 1),
#  ('كالقلق', 1),
#  ('والوسواس', 1),
#  ('والرهاب', 1),
#  ('الإجتماعي', 1),
#  ('يترتب', 1),
#  ('الأخير', 1),
#  ('تلعثم', 1),
#  ('وتأتأة', 1),
#  ('وسوء', 1),
#  ('التعبير', 1),
#  ('أحيانا', 1),
#  ('زبركسا', 1),
#  ('باروكستين', 1),
#  ('مناسب', 1),
#  ('دوائي', 1),
#  ('الفلوناكسول', 1),
#  ('صديقتي', 1),
#  ('واضبت', 1),
#  ('اخد', 1),
#  ('لمدة', 1),
#  ('سنة', 1),
#  ('ونص', 1),
#  ('واتحسنت', 1),
#  ('وقطعته', 1),
#  ('تدريجيا', 1),
#  ('استشارة', 1),
#  ('طبيبتها', 1),
#  ('وبعد', 1),
#  ('اربع', 1),
#  ('اشهر', 1),
#  ('يؤلمها', 1),
#  ('قليلا', 1),
#  ('قلبها', 1),
#  ('وبعضا', 1),
#  ('اعراض', 1),
#  ('مرحلته', 1),
#  ('الاولى', 1),
#  ('بمادا', 1),
#  ('تنصحها', 1),
#  ('قهري', 1),
#  ('بالافكار', 1),
#  ('والتخيلات', 1),
#  ('حاولت', 1),
#  ('بكل', 1),
#  ('الطرق', 1),
#  ('فائدة', 1),
#  ('زال', 1),
#  ('موجود', 1),
#  ('قرأت', 1),
#  ('يذهب', 1),
#  ('الا', 1),
#  ('بتناول', 1),
#  ('الادوية', 1),
#  ('فما', 1),
#  ('مصاب', 1),
#  ('بفشل', 1),
#  ('كلوي', 1),
#  ('توفي', 1),
#  ('ابي', 1),
#  ('مدة', 1),
#  ('لكني', 1),
#  ('البكاء', 1),
#  ('ابدا', 1),
#  ('الاول', 1),
#  ('قلت', 1),
#  ('تكون', 1),
#  ('الصدمة', 1),
#  ('احاول', 1),
#  ('اتذكر', 1),
#  ('كلامه', 1),
#  ('شيىء', 1),
#  ('يخصه', 1),
#  ('حلم', 1),
#  ('اعيش', 1),
#  ('كانه', 1),
#  ('يكن', 1),
#  ('يعطيك', 1),
#  ('العافية', 1),
#  ('كثرة', 1),
#  ('والتفكير', 1),
#  ('اكثر', 1),
#  ('الاوقات', 1),
#  ('ونادرا', 1),
#  ('افرح', 1),
#  ('الأمراض', 1),
#  ('كثيرة', 1),
#  ('والناس', 1),
#  ('كلها', 1),
#  ('جاية', 1),
#  ('عليا', 1),
#  ('شايفة', 1),
#  ('وحشة', 1),
#  ('شكل', 1),
#  ('مزاجي', 1),
#  ('بيتغير', 1),
#  ('ودايما', 1),
#  ('حتي', 1),
#  ('وقت', 1),
#  ('الفرحة', 1),
#  ('والقلق', 1),
#  ('والصراخ', 1),
#  ('بأن', 1),
#  ('أعاني', 1),
#  ('الصراع', 1),
#  ('ومنتظم', 1),
#  ('بالعلاج', 1),
#  ('القلق', 1),
#  ('حاجز', 1),
#  ('وأطر', 1),
#  ('لحجز', 1),
#  ('منفردا', 1),
#  ('الأخرين', 1),
#  ('أفيدوني', 1),
#  ('ماعلاجي', 1)]

# %%
tag=["خجل","الوسواس","الاكتئاب",]
patterns=[]
tags=[]
response=[]

# %%
for i in range(len(question)):
    response.append(data1.reponse[i])
    patterns.append(data1.Question[i])
    if any(mot in question[i]  for mot in("اكتئاب","الاكتئاب","اكتئاب","الحزن")):
        tags.append("اكتئاب")
        
    elif any( mot in question[i]  for mot in("الوسواس","وسواس","الوسواس") ):
        tags.append("الوسواس")
    else:
        tags.append('autre')

# %%
tags
# Out:
# ['autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'الوسواس',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'الوسواس',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'اكتئاب',
#  'autre',
#  'autre',
#  'الوسواس',
#  'autre',
#  'الوسواس',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'اكتئاب',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'autre',
#  'اكتئاب',
#  'autre',
#  'الوسواس',
#  'اكتئاب',
#  'autre',
#  'autre',
#  'autre',
#  'اكتئاب',
#  'الوسواس',
#  'autre',
#  'autre',
#  'اكتئاب',
#  'الوسواس',
#  'autre',
#  'الوسواس']
